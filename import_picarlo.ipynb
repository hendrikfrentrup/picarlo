# %%
import picarlo

# %%
picarlo.sim.hello()
# Out:
# inside hello!
# 'hello'

# %%
cfg = picarlo.sim.Config()

# %%
cfg.num_samples
# Out:
# 10000000

# %%
picarlo.sim.monte_carlo_pi(10000000)
# Out:
# 2025-12-01 18:03:54.964 | INFO     | picarlo.sim:monte_carlo_pi:60 - Runtime: 9.74 seconds
# Rust Runtime: 9.74s
# 3.1419388

# %%
picarlo.sim.monte_carlo_pi(10000000, force_python=True)
# Out:
# 2025-12-01 17:56:15.158 | INFO     | picarlo.sim:monte_carlo_pi:60 - Runtime: 1.22 seconds
# 3.1414016

# %%
picarlo.sim.goodbye()
# Out:
# inside goodbye!
# 'goodbye'

# %%
picarlo.sim.Config(10)
# Out:
# Config(num_samples=10)
